# %%
import pandas as pd
import os
import io

# %%
def list_files_recursive(path):
    results = []
    for entry in os.listdir(path):
        full_path = os.path.join(path, entry)
        if os.path.isdir(full_path):
            results.extend(list_files_recursive(full_path))
        else:
            results.append(full_path)
    return results

# %%
def make_dict_entry(file):
    if 'DS_Store' not in file:
        with open(file, 'r') as in_file:
            raw_text = in_file.read()

        return {
            'file': file,
            'text': raw_text,
            'sample': raw_text[0:200]
        }

# %%
files = list_files_recursive('../data/text')

# %%
records = [make_dict_entry(file) for file in files if '.DS_Store' not in file]

# %%
df = pd.DataFrame(records)

# %%
df.to_csv('../HouseFiles_TextAttachments_All.csv', index=False)
# Out:
#                                              file  \
# 0     ../data/text/001/HOUSE_OVERSIGHT_023030.txt
# 1     ../data/text/001/HOUSE_OVERSIGHT_029509.txt
# 2     ../data/text/001/HOUSE_OVERSIGHT_031346.txt
# 3     ../data/text/001/HOUSE_OVERSIGHT_023024.txt
# 4     ../data/text/001/HOUSE_OVERSIGHT_031420.txt
# ...                                           ...
# 2892  ../data/text/002/HOUSE_OVERSIGHT_032871.txt
# 2893  ../data/text/002/HOUSE_OVERSIGHT_032865.txt
# 2894  ../data/text/002/HOUSE_OVERSIGHT_032681.txt
# 2895  ../data/text/002/HOUSE_OVERSIGHT_033212.txt
# 2896  ../data/text/002/HOUSE_OVERSIGHT_033206.txt
#
#                                                    text  \
# 0     Date: Friday, March 4 2011 04:28 PM \nSubject:...
# 1     From: Deepak Chopra \nSent: 6/6/2018 11:32:09 ...
# 2     From: Nicholas Rib's__________________________...
# 3     From: Fred Haddad \nSent: 10/19/2013 12:10:27 ...
# 4     From: G Maxwell [gmax1@ellmax.com] \nSent: 9/2...
# ...                                                 ...
# 2892  From: jeffrey E. [jeeyacation@gmail.com] \nSen...
# 2893  From: jeffrey E. [jeeyacation@gmail.com] \nSen...
# 2894  From: Stephen Hanson \nSent: 12/24/2017 2:21:0...
# 2895  From: \nSent: \nTo: \nSubject: \nAttachments: ...
# 2896  From: Larry Visoski \nSent: 12/14/2016 2:34:21...
#
#                                                  sample
# 0     Date: Friday, March 4 2011 04:28 PM \nSubject:...
# 1     From: Deepak Chopra \nSent: 6/6/2018 11:32:09 ...
# 2     From: Nicholas Rib's__________________________...
# 3     From: Fred Haddad \nSent: 10/19/2013 12:10:27 ...
# 4     From: G Maxwell [gmax1@ellmax.com] \nSent: 9/2...
# ...                                                 ...
# 2892  From: jeffrey E. [jeeyacation@gmail.com] \nSen...
# 2893  From: jeffrey E. [jeeyacation@gmail.com] \nSen...
# 2894  From: Stephen Hanson \nSent: 12/24/2017 2:21:0...
# 2895  From: \nSent: \nTo: \nSubject: \nAttachments: ...
# 2896  From: Larry Visoski \nSent: 12/14/2016 2:34:21...
#
# [2897 rows x 3 columns]
